# %%
print("hello World")
# Out:
# hello World

# %%
num = [1,2,3,3,4,5,6,6,7,8,9,10]
for i in range(len(num)):
    if num[i] % 2 == 0:
        print(num[i],"is even")
    else:
        print(num[i],"is odd")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even

# %%
num=[1,2,3,3,4,5,6,6,7,8,9,10]
while num:
    n=num.pop()
    if n%2==0:
        print(n,"is even")
    else:
        print(n,"is odd")
# Out:
# 10 is even
# 9 is odd
# 8 is even
# 7 is odd
# 6 is even
# 6 is even
# 5 is odd
# 4 is even
# 3 is odd
# 3 is odd
# 2 is even
# 1 is odd

# %%
# to chek python version
import sys
print("Python version")
print(sys.version)
# Out:
# Python version
# 3.14.0 | packaged by Anaconda, Inc. | (main, Oct 22 2025, 08:58:42) [MSC v.1929 64 bit (AMD64)]

# %%
if 5 > 2:
    print("Five is greater than two! ")
# Out:
# Five is greater than two!

# %%
print("hello World")
print("Have a nice day ")
# Out:
# hello World
# Have a nice day

# %%
print("hello World");print("Have a nice day ");print("end=of line")
# Out:
# hello World
# Have a nice day
# end=of line

# %%
#print without a new line
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print("Hello World!")
print("I will print on the same line.")
# Out:
# Hello World!
# I will print on the same line.

# %%
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
print(3 + 3)
print(2 * 5)
# Out:
# 6
# 10

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %%
x = 3
print(x);print(type(x))
# Out:
# 3
# <class 'int'>

# %%
x = 3.6
print(x);print(type(x))
# Out:
# 3.6
# <class 'float'>

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
#type casting 
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0

# %%
print(type(x));print(type(y));print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
x = "John"
# is the same as
x = 'John'

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
x, y, z, w, v, u, t, s, r, q, p = "Biraj", "Bishal", "Munna", "Nandita", "Bikram","Akash","Debarshi","Pronay","Joyjit","Suvo","Piyali"
print(x)
print(y)
print(z)
print(w)
print(v)        
print(u)
print(t)    
print(s)
print(r)
print(q)
print(p)
# Out:
# Biraj
# Bishal
# Munna
# Nandita
# Bikram
# Akash
# Debarshi
# Pronay
# Joyjit
# Suvo
# Piyali

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = 5
y = "John"
print(x + y)
# you cannot combine a string and a number using the + operator. You will get an error. To fix this, you can use the str() function to convert the number to a string:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#       4 # you cannot combine a string and a number using the + operator. You will get an error. To fix this, you can use the str() function to convert the number to a string:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %%
x = "foot ball" # Global variable
def myfunc():
    print("I love to play", x)
    # print(x)
    
myfunc()
# Out:
# I love to play foot ball

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

y=myfunc()
print("value return by the funciton is ",y  )
print("Python is " + x)
# Out:
# Python is fantastic
# value return by the funciton is  None
# Python is awesome

# %%
def myfunc():
  global x # x is a global variable
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = "awesome"

def myfunc():
  global x
  x = "Pankaj is fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is Pankaj is fantastic

# %%
x = ["apple", "banana", "cherry"]
type(x)
# Out:
# list

# %%
x = ("apple", "banana", "cherry")
type(x)
# Out:
# tuple

# %%
x = {"name" : "John", "age" : 36}
type(x)
# Out:
# dict

# %%
x = {"apple", "banana", "cherry"} # it is a set
type(x)
# Out:
# set

# %%
for i in x:
  print(i)
# Out:
# cherry
# banana
# apple

# %%
x = frozenset({"apple", "banana", "cherry"}) # it is a set but immutable
type(x)
# Out:
# frozenset

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
import random

print(random.randrange(1, 10))
# Out:
# 4

# %%
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x = str("s1") # x will be 's1'
y = str(2)    # y will be '2'
z = str(3.0)  # z will be '3.0'
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
a = "Hello, World!"
print(a[1])
# Out:
# e

# %%
for i in range(len(a)):
    print(a[i])
# Out:
# H
# e
# l
# l
# o
# ,
#
# W
# o
# r
# l
# d
# !

# %%
for i in a:
    print(i)
# Out:
# H
# e
# l
# l
# o
# ,
#
# W
# o
# r
# l
# d
# !

# %%
a = "Hello,  World!" # bcz of the double space between Hello and World
print(len(a))
# Out:
# 14

# %%
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
print(b[:5])
# Out:
# Hello

# %%
print(b[0]) # indexing starts from 0, so b[0] is the first character of the string, which is "H".
# Out:
# H

# %%
print(b[-1])
# Out:
# !

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
b = "Hello, World!"
print(b[0:2]) # it will print the first two characters of the string, which are "He". The index 0 is inclusive, while index 2 is exclusive.
# Out:
# He

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
a = " Hello, World! " # white space is included at the beginning and end of the string  
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
m = ["apple", "banana", "cherry"]
type(m)
print(type(m))
# Out:
# <class 'list'>

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 3
#       1 age = 36
#       2 #This will produce an error:
# ----> 3 txt = "My name is John, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
price = 59
txt = f"The price is {price:.6f} dollars"
print(txt)
# Out:
# The price is 59.000000 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
txt = "We are the so-called "Vikings" from the north."
# Out:
#   Cell In[87], line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt   )
# Out:
# We are the so-called "Vikings" from the north.

# %%
Booleans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 Booleans
#
# NameError: name 'Booleans' is not defined

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
a = 200
b = 33

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(myobj)
print(bool(myobj))
# Out:
# ...
# False

# %%
def myFunction() :
  return True

print(myFunction())
# Out:
# True

# %%
x = 200
print(isinstance(x, int))
# Out:
# True

# %%
def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# YES!

# %%
Python Operators

# %%
x = 15
y = 4

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
print(x // y)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3

# %%
x = 12
y = 5

print(x / y)
# Out:
# 2.4

# %%
x = 12
y = 5

print(x // y)
# Out:
# 2

# %%
print(x:=435678)
# Out:
# 435678

# %%
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 435678

# %%
numbers = [1, 2, 3, 4, 5]

if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements

# %%
numbers = [1, 2, 3, 4]

if (count := len(numbers)) > 5:
    print(f"List has {count} elements")

# %%
num = 6

x = "WEEKEND!" if num > 5 else "Workday"

print(x)
# Out:
# WEEKEND!

# %%
num = 6

x = "Fri" if num == 5 else "Sat" if num == 6 else "Sun" if num == 7 else "weekday"

print(x)
# Out:
# Sat

# %%
x = 5
y = 3

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x = 5

print(1 < x < 10)

print(1 < x and x < 10)
# Out:
# True
# True

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
id(x)==id(z)
# Out:
# True

# %%
id(y)
# Out:
# 2277020475200

# %%
x = [1, 2, 3]
y = [1, 2, 3]

print(x == y)
print(x is y)
# Out:
# True
# False

# %%
fruits = ["apple", "banana", "cherry"]

print("pineapple" not in fruits)
# Out:
# True

# %%
print(6 & 3)
# The binary representation of 6 is 0110
# The binary representation of 3 is 0011

# Then the & operator compares the bits and returns 0010, which is 2 in decimal.
# Out:
# 2

# %%
print(6 | 3)
# The binary representation of 6 is 0110
# The binary representation of 3 is 0011

# Then the | operator compares the bits and returns 0111, which is 7 in decimal.
# Out:
# 7

# %%
#XOR
print(6^3)
# he binary representation of 6 is 0110
# The binary representation of 3 is 0011

# Then the ^ operator compares the bits and returns 0101, which is 5 in decimal.
# Out:
# 5

# %%
print(5 + 4 - 7 + 3)
# Out:
# 5

# %%
# List

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

# %%
list1 = ["abc", 34, True, 40, "male"]

# %%
mylist = ["apple", "banana", "cherry"]
print(type(mylist))
# Out:
# <class 'list'>

# %%
thelist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thelist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(type(thelist  ))
# Out:
# <class 'list'>

# %%
# Python Collections (Arrays)
# There are four collection data types in the Python programming language:

# List is a collection which is ordered and changeable. Allows duplicate members.
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
# Note: The length of the list will change when the number of items inserted does not match the number of items replaced.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
nums = [2, 7, 11, 15]

# %%
nums[0]
# Out:
# 2

# %%
nums[1]
# index:   0   1    2    3
# value:   2   7   11   15
# Out:
# 7

# %%
for i, x in enumerate(nums):
    print(i, x)
# Out:
# 0 2
# 1 7
# 2 11
# 3 15

# %%
for i ,x in enumerate(nums):
    print(i,x)
# Out:
# 0 2
# 1 7
# 2 11
# 3 15

# %%
seen = {}
type(seen)
# Out:
# dict

# %%
seen = {
    2: 0,
    7: 1
}
print(seen)
# Out:
# {2: 0, 7: 1}

# %%
type(seen)
# Out:
# dict

# %%
if 7 in seen:
    ...
    print("7 is present in the dictionary")
# Out:
# 7 is present in the dictionary

# %%
seen[7]
# Out:
# 1

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """

        seen = {} # Dictionary to store the numbers we have seen and their indices
        # print(seen)
        for i, num in enumerate(nums):

            complement = target - num
            # print(seen)
            if complement in seen:
                return [seen[complement], i]

            seen[num] = i
            
        # print(seen)
        
        # for i ,x in enumerate(nums):
        #     print(i,x)

# %%
solution = Solution()

answer = solution.twoSum([2, 7, 11, 15], 9)
print(answer)
# Out:
# {}
# {2: 0}
# [0, 1]

# %%
seen = {
    20:0,
        8:1}

# %%
seen[20]
# Out:
# 0

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
thislist.clear()
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
# []

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
for x in thislist:
    print(x)
# Out:
# apple
# cherry

# %%
L1 = ["apple", "banana", "cherry"]
for i in range(len(L1)):
    print(L1[i])
# Out:
# apple
# banana
# cherry

# %%
L1 = ["apple", "banana", "cherry"]
i = 0
while i < len(L1):
  print(L1[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
L1 = ["apple", "banana", "cherry"]
print([print(x) for x in L1])
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
L1 = ["apple", "banana", "cherry"]
newL1 =[]
for x in L1:
    newL1.append(x.upper())
print(newL1)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
mytuple = ("apple", "banana", "cherry")

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
thistuple = ()
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)

# %%
tuple1 = ("abc", 34, True, 40, "male")

# %%
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)


print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple
print(thistuple) #this will raise an error because the tuple no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[243], line 3
#       1 thistuple = ("apple", "banana", "cherry")
#       2 del thistuple
# ----> 3 print(thistuple) #this will raise an error because the tuple no longer exists
#
# NameError: name 'thistuple' is not defined

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)

# %%
# Unpacking a tuple:

fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
# Unpacking a tuple:

fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
    print(thistuple[i])
    i = i +1
# Out:
# apple
# banana
# cherry

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")


print(thisset)
# Out:
# {'cherry', 'banana', 'orange', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'pineapple', 'papaya', 'apple', 'cherry', 'mango', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'orange', 'apple', 'banana', 'kiwi', 'cherry'}

# %%
def swap(a,b):
    a,b = b,a
    return a,b  

swap(50, 100)
# Out:
# (100, 50)

# %%
a =30
b = 20
print("Before swapping: a =", a, "b =", b)
b = a+b # b becomes 50
a = b-a # a becomes 20
b = b-a # b becomes 30
print("After swapping: a =", a, "b =", b)
# Out:
# Before swapping: a = 30 b = 20
# After swapping: a = 20 b = 30
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
